# %% [markdown]
# ## Graded Lab: Reflection in a Research Agent
#
# In this graded lab, you’ll implement a simple **agentic workflow** designed to simulate reflective thinking in a writing task. This is one building block of a more complex research agent that will be constructed throughout the course.
#
# ### Objective
#
# Build a three-step workflow where an LLM writes an essay draft, critiques it, and rewrites it.
#
# * **Step 1 – Drafting:** Call the LLM to generate an initial draft of an essay based on a simple prompt.
# * **Step 2 – Reflection:** Reflect on the draft using a reasoning step. (Optionally, this can be done with a different model.)
# * **Step 3 – Revision:** Apply the feedback from the reflection to generate a revised version of the essay.

# %% [markdown]
# ---
# <a name='submission'></a>
#
# <h4 style="color:green; font-weight:bold;">TIPS FOR SUCCESSFUL GRADING OF YOUR ASSIGNMENT:</h4>
#
# * All cells are frozen except for the ones where you need to write your solution code or when explicitly mentioned you can interact with it.
#
# * In each exercise cell, look for comments `### START CODE HERE ###` and `### END CODE HERE ###`. These show you where to write the solution code. **Do not add or change any code that is outside these comments**.
#
# * You can add new cells to experiment but these will be omitted by the grader, so don't rely on newly created cells to host your solution code, use the provided places for this.
#
# * Avoid using global variables unless you absolutely have to. The grader tests your code in an isolated environment without running all cells from the top. As a result, global variables may be unavailable when scoring your submission. Global variables that are meant to be used will be defined in UPPERCASE.
#
# * To submit your notebook for grading, first save it by clicking the 💾 icon on the top left of the page and then click on the <span style="background-color: red; color: white; padding: 3px 5px; font-size: 16px; border-radius: 5px;">Submit assignment</span> button on the top right of the page.
# ---

# %% [markdown]
# Before interacting with the language models, we initialize the `aisuite` client. This setup loads environment variables (e.g., API keys) from a `.env` file to securely authenticate with backend services. The `ai.Client()` instance will be used to make all model calls throughout this workflow.

# %%
from dotenv import load_dotenv

load_dotenv()

import aisuite as ai

# Define the client. You can use this variable inside your graded functions!
CLIENT = ai.Client()

# %%
import unittests

# %% [markdown]
# ## Exercise 1: `generate_draft` Function
#
# **Objective**:
# Write a function called `generate_draft` that takes in a string topic and uses a language model to generate a complete draft essay.
#
# **Inputs**:
#
# * `topic` (str): The essay topic.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string representing the full draft of the essay.
#
# The setup for calling the LLM using the aisuite library is already provided. Focus on crafting the prompt content. You can reference this setup in later exercises to understand how to interact with the library effectively.

# %%
# GRADED FUNCTION: generate_draft

def generate_draft(topic: str, model: str = "openai:gpt-4o") -> str: 
    
    prompt = f"""
        Write a complete, well organized essay on the following topic:

        "{topic}"

        The essay should include:
        - A clear introduction that presents the topic and main idea
        - Several body paragraphs that develop the argument with explanations or examples
        - A concluding paragraph that summarizes the key points and provides closure

        Write in a clear, neutral, and informative tone. Do not include headings, bullet points, or meta commentary. Present the essay as a continuous piece of prose.
    """
    
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %% [markdown]
# Run the following cell to check your code is working correctly:

# %%
# Test your code!
unittests.test_generate_draft(generate_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 2: `reflect_on_draft` Function
#
# **Objective**:
# Write a function called `reflect_on_draft` that takes a previously generated essay draft and uses a language model to provide constructive feedback.
#
# **Inputs**:
#
# * `draft` (str): The essay text to reflect on.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:o4-mini"`.
#
# **Output**:
#
# * A string with feedback in paragraph form.
#
# **Requirements**:
#
# * The feedback should be critical but constructive.
# * It should address issues such as structure, clarity, strength of argument, and writing style.
# * The function should send the draft to the model and return its response.
#
# You do **not** need to rewrite the essay at this step—just analyze and reflect on it.

# %%
# GRADED FUNCTION: reflect_on_draft

def reflect_on_draft(draft: str, model: str = "openai:o4-mini") -> str:

    prompt = f"""
        You are a writing reviewer. Carefully read the essay draft below and provide constructive, critical feedback.

        Focus your feedback on:
        - Overall structure and organization
        - Clarity of ideas and flow between paragraphs
        - Strength and coherence of the main argument
        - Writing style, tone, and readability

        Do not rewrite the essay. Do not provide bullet points or headings. 
        Return your feedback as one or more well structured paragraphs written in a professional and helpful tone.

        Essay draft:
        \"\"\"
        {draft}
        \"\"\"
    """

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_reflect_on_draft(reflect_on_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 3: `revise_draft` Function
#
# **Objective**:
# Implement a function called `revise_draft` that improves a given essay draft based on feedback from a reflection step.
#
# **Inputs**:
#
# * `original_draft` (str): The initial version of the essay.
# * `reflection` (str): Constructive feedback or critique on the draft.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string containing the revised and improved essay.
#
# **Requirements**:
#
# * The revised draft should address the issues mentioned in the feedback.
# * It should improve clarity, coherence, argument strength, and overall flow.
# * The function should use the feedback to guide the revision, and return only the final revised essay.
#
# In this final exercise, you'll also need to manage the call to the LLM using the CLIENT, as you've practiced in previous exercises.

# %%
# GRADED FUNCTION: revise_draft

def revise_draft(original_draft: str, reflection: str, model: str = "openai:gpt-4o") -> str:

    prompt = f"""
        You are an experienced editor. Revise the essay below using the provided feedback.

        Your goals are to:
        - Address all substantive issues raised in the feedback
        - Improve clarity, organization, and logical flow
        - Strengthen the central argument where appropriate
        - Refine writing style while preserving the original intent

        Do not explain your changes. Do not include commentary, notes, or headings.
        Return only the revised essay as a complete piece of prose.

        Original essay:
        \"\"\"
        {original_draft}
        \"\"\"

        Feedback:
        \"\"\"
        {reflection}
        \"\"\"
    """

    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    ### END CODE HERE ###

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_revise_draft(revise_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ### 🧪 Test the Reflective Writing Workflow
#
# Use the functions you implemented to simulate the complete writing workflow:
#
# 1. **Generate a draft** in response to the essay prompt.
# 2. **Reflect** on the draft to identify improvements.
# 3. **Revise** the draft using the feedback.
#
# Observe the outputs of each step. You do **not** need to modify the outputs — just verify that the workflow runs as expected and each component returns a valid string.

# %%
essay_prompt = "Should social media platforms be regulated by the government?"

# Agent 1 – Draft
draft = generate_draft(essay_prompt)
print("📝 Draft:\n")
print(draft)

# Agent 2 – Reflection
feedback = reflect_on_draft(draft)
print("\n🧠 Feedback:\n")
print(feedback)

# Agent 3 – Revision
revised = revise_draft(draft, feedback)
print("\n✍️ Revised:\n")
print(revised)
# Out:
# 📝 Draft:
#
# The advent of social media has transformed the way individuals communicate, access information, and engage with the world around them. Platforms such as Facebook, Twitter, and Instagram have become integral to modern life, influencing everything from personal relationships to global political dynamics. However, alongside the benefits of these digital platforms, concerns have emerged about their impact on privacy, misinformation, and societal polarization. Consequently, the question of whether social media platforms should be regulated by the government has sparked significant debate. This essay explores the arguments for and against government regulation of social media platforms to assess whether such regulation is necessary and appropriate.
#
# Proponents of government regulation argue that social media platforms wield substantial power over the flow of information and can significantly influence public opinion. Without regulatory oversight, these platforms may prioritize profit over the public good, allowing harmful content, such as hate speech and misinformation, to spread unchecked. For example, during election cycles, platforms have been criticized for allowing the dissemination of false information that can misguide voters. Government regulation could establish clearer standards and accountability measures, ensuring that users receive accurate information and that platforms take responsibility for preventing the spread of harmful content.
#
# Moreover, social media platforms are often criticized for insufficient protection of user data and privacy. Instances of data breaches and the exploitation of personal information for targeted advertising have raised ethical concerns. By implementing regulations, the government could enforce stricter data protection protocols, safeguarding users' personal information from misuse. This regulation would not only protect individual privacy but also enhance trust in digital platforms, promoting a safer online environment.
#
# Opponents, however, argue that government regulation of social media presents significant risks to freedom of expression and innovation. Social media platforms have democratized content creation, providing a voice to individuals who were traditionally marginalized in mainstream media. Government intervention could lead to censorship or the suppression of unpopular opinions, stifling the diverse range of perspectives that social media provides. Additionally, overregulation might hinder technological innovation and the development of new features or platforms, limiting the dynamic nature of social media.
#
# Furthermore, the global nature of social media presents challenges to effective government regulation. Platforms operate across borders, with users from diverse legal and cultural backgrounds. A regulatory approach tailored to one nation may not be applicable or effective in another, complicating enforcement efforts. International cooperation and a nuanced understanding of regional contexts would be necessary to develop regulations that maintain the balance between protecting users and preserving platform freedoms.
#
# In conclusion, the question of whether social media platforms should be regulated by the government involves weighing the benefits of maintaining user privacy and preventing harmful content against the risks of stifling free expression and innovation. While government regulation could address pressing concerns such as misinformation and data privacy, it also presents the risk of overreach and unintended restrictions on freedom. Striking a balance will require careful consideration of the unique challenges social media presents, as well as ongoing dialogue between governments, platforms, and civil society. As the digital landscape continues to evolve, it is imperative that any regulatory measures keep pace with the changes while safeguarding the fundamental principles of freedom and innovation.
#
# 🧠 Feedback:
#
# The draft offers a clear and conventional progression from introduction through supporting and opposing viewpoints to conclusion, establishing the central question of government regulation of social media early on and maintaining focus on it throughout. The introduction effectively situates the reader by naming prominent platforms and outlining emerging concerns, but the thesis might benefit from a slightly more forceful articulation of the essay’s ultimate stance. As it stands, the conclusion reiterates the competing interests of privacy, misinformation, and freedom of expression without signaling a decisive position, which can leave the reader wanting a more definitive sense of the author’s perspective or proposed path forward.
#
# Within the body paragraphs, each section is organized around a logical claim—first the advantages of regulation in curbing misinformation and protecting user data, then the potential pitfalls in terms of censorship and technological stagnation. While this binary structure is easy to follow, transitions between paragraphs feel somewhat abrupt. For instance, a brief linking sentence at the end of the privacy paragraph could more smoothly introduce the freedom-of-expression concern that follows. Additionally, the examples cited (election misinformation, data breaches) are pertinent, but the discussion would gain depth from more specific instances or data on regulatory success and failure, which in turn would bolster the argument’s credibility and give each point greater texture.
#
# Stylistically, the tone is suitably formal and balanced, yet many sentences begin in similar ways or follow parallel syntax, lending a somewhat monotonal rhythm to the prose. Varying sentence length and structure—perhaps by interspersing an emphatic short statement or a rhetorical question—would heighten reader engagement. A more dynamic use of active voice and occasional illustrative anecdotes or quotations from policymakers, technologists, or users could also enrich readability. Finally, a more compelling conclusion might not only restate the tension between safety and innovation but suggest a vision for how that balance might practically be achieved, leaving the reader with a clear, memorable takeaway.
#
# ✍️ Revised:
#
# The advent of social media has fundamentally transformed communication, access to information, and global engagement. Platforms like Facebook, Twitter, and Instagram are now woven into the fabric of modern life, shaping personal relationships and political dynamics worldwide. Amidst the undeniable benefits these platforms provide, concerns about their impact on privacy, misinformation, and societal polarization have emerged. This debate gives rise to the pressing question: Should the government regulate social media platforms? This essay delves into the arguments surrounding this issue to determine the necessity and appropriateness of such regulation.
#
# Proponents of government regulation assert that social media platforms hold significant sway over information dissemination and can shape public opinion. Without regulatory oversight, profit motives might overshadow the public good, allowing the unchecked spread of harmful content such as hate speech and misinformation. During election cycles, for instance, platforms have faced criticism for enabling the spread of false information that misleads voters. Government regulation could establish standards and accountability measures, ensuring that users receive accurate information and that platforms actively prevent the spread of deceitful content.
#
# Moreover, these platforms often fall short in safeguarding user data and privacy. Instances of data breaches and the misuse of personal information for targeted advertising have raised ethical alarms. Regulation could enforce robust data protection protocols, protecting users from exploitation and fostering trust in digital platforms. This approach not only upholds individual privacy but also cultivates a safer online environment.
#
# Conversely, opponents argue that regulating social media could threaten freedom of expression and innovation. These platforms democratize content creation, giving a voice to traditionally marginalized individuals. Government intervention might lead to censorship, suppressing unpopular opinions and stifling the diverse perspectives that social media accommodates. Overregulation could also stifle technological innovation, hindering the development of new features and platforms.
#
# Additionally, the global nature of social media amplifies the challenges of effective regulation. Platforms transcend borders, serving users with diverse legal and cultural backgrounds. Regulations tailored to one nation may prove ineffective elsewhere, complicating enforcement efforts. Achieving a balanced regulatory framework would require international cooperation and a nuanced understanding of regional contexts.
#
# Ultimately, the dilemma of government regulation of social media platforms involves balancing the protection of user privacy and the prevention of harmful content against the risks to free expression and innovation. While regulation could tackle pressing issues like misinformation and data privacy, it also risks overreach and unintended restrictions on freedom. To achieve this balance, stakeholders must engage in ongoing dialogue, crafting measures that adapt to the evolving digital landscape while safeguarding fundamental principles of freedom and innovation. By envisioning a collaborative regulatory approach, we can strive for a future where social media remains a constructive force for communication and progress.

# %% [markdown]
# To better visualize the output of each step in the reflective writing workflow, we use a utility function called `show_output`. This function displays the results of each stage (drafting, reflection, and revision) in styled boxes with custom background and text colors, making it easier to compare and understand the progression of the essay.

# %%
from utils import show_output

essay_prompt = "Should social media platforms be regulated by the government?"

show_output("Step 1 – Draft", draft, background="#fff8dc", text_color="#333333")
show_output("Step 2 – Reflection", feedback, background="#e0f7fa", text_color="#222222")
show_output("Step 3 – Revision", revised, background="#f3e5f5", text_color="#222222")
# Out:
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #fff8dc;
#         color: #333333;
#     ">
#         <h3 style="margin-top: 0;">Step 1 – Draft</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">The advent of social media has transformed the way individuals communicate, access information, and engage with the world around them. Platforms such as Facebook, Twitter, and Instagram have become integral to modern life, influencing everything from personal relationships to global political dynamics. However, alongside the benefits of these digital platforms, concerns have emerged about their impact on privacy, misinformation, and societal polarization. Consequently, the question of whether social media platforms should be regulated by the government has sparked significant debate. This essay explores the arguments for and against government regulation of social media platforms to assess whether such regulation is necessary and appropriate.
#
# Proponents of government regulation argue that social media platforms wield substantial power over the flow of information and can significantly influence public opinion. Without regulatory oversight, these platforms may prioritize profit over the public good, allowing harmful content, such as hate speech and misinformation, to spread unchecked. For example, during election cycles, platforms have been criticized for allowing the dissemination of false information that can misguide voters. Government regulation could establish clearer standards and accountability measures, ensuring that users receive accurate information and that platforms take responsibility for preventing the spread of harmful content.
#
# Moreover, social media platforms are often criticized for insufficient protection of user data and privacy. Instances of data breaches and the exploitation of personal information for targeted advertising have raised ethical concerns. By implementing regulations, the government could enforce stricter data protection protocols, safeguarding users' personal information from misuse. This regulation would not only protect individual privacy but also enhance trust in digital platforms, promoting a safer online environment.
#
# Opponents, however, argue that government regulation of social media presents significant risks to freedom of expression and innovation. Social media platforms have democratized content creation, providing a voice to individuals who were traditionally marginalized in mainstream media. Government intervention could lead to censorship or the suppression of unpopular opinions, stifling the diverse range of perspectives that social media provides. Additionally, overregulation might hinder technological innovation and the development of new features or platforms, limiting the dynamic nature of social media.
#
# Furthermore, the global nature of social media presents challenges to effective government regulation. Platforms operate across borders, with users from diverse legal and cultural backgrounds. A regulatory approach tailored to one nation may not be applicable or effective in another, complicating enforcement efforts. International cooperation and a nuanced understanding of regional contexts would be necessary to develop regulations that maintain the balance between protecting users and preserving platform freedoms.
#
# In conclusion, the question of whether social media platforms should be regulated by the government involves weighing the benefits of maintaining user privacy and preventing harmful content against the risks of stifling free expression and innovation. While government regulation could address pressing concerns such as misinformation and data privacy, it also presents the risk of overreach and unintended restrictions on freedom. Striking a balance will require careful consideration of the unique challenges social media presents, as well as ongoing dialogue between governments, platforms, and civil society. As the digital landscape continues to evolve, it is imperative that any regulatory measures keep pace with the changes while safeguarding the fundamental principles of freedom and innovation.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #e0f7fa;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 2 – Reflection</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">The draft offers a clear and conventional progression from introduction through supporting and opposing viewpoints to conclusion, establishing the central question of government regulation of social media early on and maintaining focus on it throughout. The introduction effectively situates the reader by naming prominent platforms and outlining emerging concerns, but the thesis might benefit from a slightly more forceful articulation of the essay’s ultimate stance. As it stands, the conclusion reiterates the competing interests of privacy, misinformation, and freedom of expression without signaling a decisive position, which can leave the reader wanting a more definitive sense of the author’s perspective or proposed path forward.
#
# Within the body paragraphs, each section is organized around a logical claim—first the advantages of regulation in curbing misinformation and protecting user data, then the potential pitfalls in terms of censorship and technological stagnation. While this binary structure is easy to follow, transitions between paragraphs feel somewhat abrupt. For instance, a brief linking sentence at the end of the privacy paragraph could more smoothly introduce the freedom-of-expression concern that follows. Additionally, the examples cited (election misinformation, data breaches) are pertinent, but the discussion would gain depth from more specific instances or data on regulatory success and failure, which in turn would bolster the argument’s credibility and give each point greater texture.
#
# Stylistically, the tone is suitably formal and balanced, yet many sentences begin in similar ways or follow parallel syntax, lending a somewhat monotonal rhythm to the prose. Varying sentence length and structure—perhaps by interspersing an emphatic short statement or a rhetorical question—would heighten reader engagement. A more dynamic use of active voice and occasional illustrative anecdotes or quotations from policymakers, technologists, or users could also enrich readability. Finally, a more compelling conclusion might not only restate the tension between safety and innovation but suggest a vision for how that balance might practically be achieved, leaving the reader with a clear, memorable takeaway.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #f3e5f5;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 3 – Revision</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">The advent of social media has fundamentally transformed communication, access to information, and global engagement. Platforms like Facebook, Twitter, and Instagram are now woven into the fabric of modern life, shaping personal relationships and political dynamics worldwide. Amidst the undeniable benefits these platforms provide, concerns about their impact on privacy, misinformation, and societal polarization have emerged. This debate gives rise to the pressing question: Should the government regulate social media platforms? This essay delves into the arguments surrounding this issue to determine the necessity and appropriateness of such regulation.
#
# Proponents of government regulation assert that social media platforms hold significant sway over information dissemination and can shape public opinion. Without regulatory oversight, profit motives might overshadow the public good, allowing the unchecked spread of harmful content such as hate speech and misinformation. During election cycles, for instance, platforms have faced criticism for enabling the spread of false information that misleads voters. Government regulation could establish standards and accountability measures, ensuring that users receive accurate information and that platforms actively prevent the spread of deceitful content.
#
# Moreover, these platforms often fall short in safeguarding user data and privacy. Instances of data breaches and the misuse of personal information for targeted advertising have raised ethical alarms. Regulation could enforce robust data protection protocols, protecting users from exploitation and fostering trust in digital platforms. This approach not only upholds individual privacy but also cultivates a safer online environment.
#
# Conversely, opponents argue that regulating social media could threaten freedom of expression and innovation. These platforms democratize content creation, giving a voice to traditionally marginalized individuals. Government intervention might lead to censorship, suppressing unpopular opinions and stifling the diverse perspectives that social media accommodates. Overregulation could also stifle technological innovation, hindering the development of new features and platforms.
#
# Additionally, the global nature of social media amplifies the challenges of effective regulation. Platforms transcend borders, serving users with diverse legal and cultural backgrounds. Regulations tailored to one nation may prove ineffective elsewhere, complicating enforcement efforts. Achieving a balanced regulatory framework would require international cooperation and a nuanced understanding of regional contexts.
#
# Ultimately, the dilemma of government regulation of social media platforms involves balancing the protection of user privacy and the prevention of harmful content against the risks to free expression and innovation. While regulation could tackle pressing issues like misinformation and data privacy, it also risks overreach and unintended restrictions on freedom. To achieve this balance, stakeholders must engage in ongoing dialogue, crafting measures that adapt to the evolving digital landscape while safeguarding fundamental principles of freedom and innovation. By envisioning a collaborative regulatory approach, we can strive for a future where social media remains a constructive force for communication and progress.</pre>
#     </div>

# %% [markdown]
# ## Check grading feedback
#
# If you have collapsed the right panel to have more screen space for your code, as shown below:
#
# <img src="./images/collapsed.png" alt="Collapsed Image" width="800" height="400"/>
#
# You can click on the left-facing arrow button (highlighted in red) to view feedback for your submission after submitting it for grading. Once expanded, it should display like this:
#
# <img src="./images/expanded.png" alt="Expanded Image" width="800" height="400"/>
